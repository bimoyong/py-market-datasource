# %%
import io
import logging
import subprocess
import sys
import warnings
from contextlib import suppress
from datetime import timedelta
from functools import reduce
from logging import StreamHandler
from os import chdir, getcwd, makedirs
from os.path import dirname, exists, join
from subprocess import CalledProcessError, check_output
from typing import List

import humanize
import numpy as np
import pandas as pd
import pandas_ta as ta
from google import auth
from google.cloud import bigquery
from moonshot.strategies.base import Moonshot
from numpy import nan
from pandas.testing import assert_frame_equal, assert_series_equal

if exists('/codeload'):
    WORK_DIR = '/codeload'
else:
    base_dir = check_output(['git', 'rev-parse', '--show-toplevel']).strip().decode()
    WORK_DIR = join(base_dir, 'src')
    sys.path.extend([base_dir,
                    join(base_dir, 'src'),
                    join(base_dir, 'notebook'),
                    join(base_dir, 'notebook/*')])

chdir(WORK_DIR)


warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.8f}'.format

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
logger.addHandler(StreamHandler())

# %%
# %set_env GOOGLE_APPLICATION_CREDENTIALS $base_dir/credentials/service_account.json

CREDENTIALS, PROJECT_ID = auth.default()
REGION = 'asia-southeast1'

# %set_env GCLOUD_PROJECT $PROJECT_ID
# %set_env REGION $REGION
# Out:
# env: GOOGLE_APPLICATION_CREDENTIALS=/Users/trung/Projects/tkteam/py-datasource/credentials/service_account.json
# env: GCLOUD_PROJECT=trading-strategy-develop
# env: REGION=asia-southeast1

# %%
from src.data_providers.data_provider import DataProvider
from src.data_providers.tradingview_provider import TradingViewProvider
# Out:
# env: GCLOUD_PROJECT=trading-strategy-develop
# env: REGION=asia-southeast1

# %%
provider: DataProvider = TradingViewProvider()
provider.TOKEN = ''
provider.WORKERS_NO = 4

# %%
results = provider.economic_calendar(from_date='2024-06-16',
                                     to_date='2024-06-23',
                                     fetch_related_events=True,
                                     countries=['US', 'CA'])

# %%
results
# Out:
# [{'id': '352967',
#   'title': 'Housing Starts',
#   'country': 'CA',
#   'indicator': 'Housing Starts',
#   'ticker': 'ECONOMICS:CAHST',
#   'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#   'category': 'hse',
#   'period': 'May',
#   'source': 'Mortgage and Housing Corporation',
#   'source_url': 'https://www.cmhc-schl.gc.ca',
#   'actual': 264.5,
#   'previous': 241.1,
#   'forecast': 247,
#   'actualRaw': 264500,
#   'previousRaw': 241100,
#   'forecastRaw': 247000,
#   'currency': 'CAD',
#   'scale': 'K',
#   'importance': 0,
#   'date': '2024-06-17T12:15:00.000Z',
#   'events': [{'id': '329108',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Sep',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 270.5,
#     'previous': 250.4,
#     'forecast': 240,
#     'actualRaw': 270500,
#     'previousRaw': 250400,
#     'forecastRaw': 240000,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2023-10-18T12:15:00.000Z'},
#    {'id': '330666',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Oct',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 274.7,
#     'previous': 270.7,
#     'forecast': 252.9,
#     'actualRaw': 274700,
#     'previousRaw': 270700,
#     'forecastRaw': 252900,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2023-11-16T13:15:00.000Z'},
#    {'id': '332352',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Nov',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 212.6,
#     'previous': 272.3,
#     'forecast': 257.1,
#     'actualRaw': 212600,
#     'previousRaw': 272300,
#     'forecastRaw': 257100.00000000003,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2023-12-15T13:15:00.000Z'},
#    {'id': '345513',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Dec',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 249.3,
#     'previous': 210.9,
#     'forecast': 243,
#     'actualRaw': 249300,
#     'previousRaw': 210900,
#     'forecastRaw': 243000,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2024-01-16T13:15:00.000Z'},
#    {'id': '346919',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Jan',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 223.6,
#     'previous': 249,
#     'forecast': 235,
#     'actualRaw': 223600,
#     'previousRaw': 249000,
#     'forecastRaw': 235000,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2024-02-15T13:15:00.000Z'},
#    {'id': '348480',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Feb',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 253.5,
#     'previous': 223.2,
#     'forecast': 230,
#     'actualRaw': 253500,
#     'previousRaw': 223200,
#     'forecastRaw': 230000,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2024-03-15T12:15:00.000Z'},
#    {'id': '350119',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Mar',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 242.2,
#     'previous': 260,
#     'forecast': 244,
#     'actualRaw': 242200,
#     'previousRaw': 260000,
#     'forecastRaw': 244000,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2024-04-16T12:15:00.000Z'},
#    {'id': '351369',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Apr',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 240.2,
#     'previous': 242.3,
#     'forecast': 238,
#     'actualRaw': 240200,
#     'previousRaw': 242300,
#     'forecastRaw': 238000,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2024-05-15T12:15:00.000Z'},
#    {'id': '352967',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'May',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': 264.5,
#     'previous': 241.1,
#     'forecast': 247,
#     'actualRaw': 264500,
#     'previousRaw': 241100,
#     'forecastRaw': 247000,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2024-06-17T12:15:00.000Z'},
#    {'id': '354504',
#     'title': 'Housing Starts',
#     'country': 'CA',
#     'indicator': 'Housing Starts',
#     'ticker': 'ECONOMICS:CAHST',
#     'comment': 'In Canada, a housing start is defined as the beginning of construction work on the building where the dwelling unit will be located. This can be described in 2 ways: usually, the stage when the concrete has been poured for the whole of the footing around the structure; or an equivalent stage where a basement will not be part of the structure.',
#     'category': 'hse',
#     'period': 'Jun',
#     'source': 'Mortgage and Housing Corporation',
#     'source_url': 'https://www.cmhc-schl.gc.ca',
#     'actual': None,
#     'previous': 264.5,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': 264500,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'scale': 'K',
#     'importance': 0,
#     'date': '2024-07-16T12:15:00.000Z'}]},
#  {'id': '352975',
#   'title': 'NY Empire State Manufacturing Index',
#   'country': 'US',
#   'indicator': 'Ny Empire State Manufacturing Index',
#   'ticker': 'ECONOMICS:USNYESMI',
#   'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of New York',
#   'source_url': 'https://www.newyorkfed.org',
#   'actual': -6,
#   'previous': -15.6,
#   'forecast': -9,
#   'actualRaw': -6,
#   'previousRaw': -15.6,
#   'forecastRaw': -9,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-17T12:30:00.000Z',
#   'events': [{'id': '329078',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Oct',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -4.6,
#     'previous': 1.9,
#     'forecast': -7,
#     'actualRaw': -4.6,
#     'previousRaw': 1.9,
#     'forecastRaw': -7,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2023-10-16T12:30:00.000Z'},
#    {'id': '330592',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Nov',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': 9.1,
#     'previous': -4.6,
#     'forecast': -2.8,
#     'actualRaw': 9.1,
#     'previousRaw': -4.6,
#     'forecastRaw': -2.8,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2023-11-15T13:30:00.000Z'},
#    {'id': '332357',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Dec',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -14.5,
#     'previous': 9.1,
#     'forecast': 2,
#     'actualRaw': -14.5,
#     'previousRaw': 9.1,
#     'forecastRaw': 2,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2023-12-15T13:30:00.000Z'},
#    {'id': '345516',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Jan',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -43.7,
#     'previous': -14.5,
#     'forecast': -5,
#     'actualRaw': -43.7,
#     'previousRaw': -14.5,
#     'forecastRaw': -5,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2024-01-16T13:30:00.000Z'},
#    {'id': '346921',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Feb',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -2.4,
#     'previous': -43.7,
#     'forecast': -15,
#     'actualRaw': -2.4,
#     'previousRaw': -43.7,
#     'forecastRaw': -15,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2024-02-15T13:30:00.000Z'},
#    {'id': '348497',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Mar',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -20.9,
#     'previous': -2.4,
#     'forecast': -7,
#     'actualRaw': -20.9,
#     'previousRaw': -2.4,
#     'forecastRaw': -7,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2024-03-15T12:30:00.000Z'},
#    {'id': '349967',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Apr',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -14.3,
#     'previous': -20.9,
#     'forecast': -9,
#     'actualRaw': -14.3,
#     'previousRaw': -20.9,
#     'forecastRaw': -9,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2024-04-15T12:30:00.000Z'},
#    {'id': '351372',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'May',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -15.6,
#     'previous': -14.3,
#     'forecast': -10,
#     'actualRaw': -15.6,
#     'previousRaw': -14.3,
#     'forecastRaw': -10,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2024-05-15T12:30:00.000Z'},
#    {'id': '352975',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Jun',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': -6,
#     'previous': -15.6,
#     'forecast': -9,
#     'actualRaw': -6,
#     'previousRaw': -15.6,
#     'forecastRaw': -9,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2024-06-17T12:30:00.000Z'},
#    {'id': '354480',
#     'title': 'NY Empire State Manufacturing Index',
#     'country': 'US',
#     'indicator': 'Ny Empire State Manufacturing Index',
#     'ticker': 'ECONOMICS:USNYESMI',
#     'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#     'category': 'bsnss',
#     'period': 'Jul',
#     'source': 'Federal Reserve Bank of New York',
#     'source_url': 'https://www.newyorkfed.org',
#     'actual': None,
#     'previous': -6,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': -6,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': 0,
#     'date': '2024-07-15T12:30:00.000Z'}]},
#  {'id': '353072',
#   'title': 'Foreign Securities Purchases',
#   'country': 'CA',
#   'indicator': 'Foreign Stock Investment',
#   'ticker': 'ECONOMICS:CAFSI',
#   'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#   'category': 'mny',
#   'period': 'Apr',
#   'source': 'Statistics Canada',
#   'source_url': 'https://www.statcan.gc.ca',
#   'actual': 41.16,
#   'previous': 14.38,
#   'forecast': 12.3,
#   'actualRaw': 41160000000,
#   'previousRaw': 14380000000,
#   'forecastRaw': 12300000000,
#   'currency': 'CAD',
#   'unit': 'C$',
#   'scale': 'B',
#   'importance': -1,
#   'date': '2024-06-17T12:30:00.000Z',
#   'events': [{'id': '329110',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Aug',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': -8.47,
#     'previous': 13.93,
#     'forecast': 11.78,
#     'actualRaw': -8470000000.000001,
#     'previousRaw': 13930000000,
#     'forecastRaw': 11780000000,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2023-10-17T12:30:00.000Z'},
#    {'id': '330786',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Sep',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': -15.09,
#     'previous': -8.77,
#     'forecast': None,
#     'actualRaw': -15090000000,
#     'previousRaw': -8770000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2023-11-17T13:30:00.000Z'},
#    {'id': '332358',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Oct',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': -15.75,
#     'previous': -15.06,
#     'forecast': -3.98,
#     'actualRaw': -15750000000,
#     'previousRaw': -15060000000,
#     'forecastRaw': -3980000000,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2023-12-15T13:30:00.000Z'},
#    {'id': '345514',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Nov',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 11.43,
#     'previous': -15.88,
#     'forecast': None,
#     'actualRaw': 11430000000,
#     'previousRaw': -15880000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-01-17T13:30:00.000Z'},
#    {'id': '347036',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Dec',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 10.44,
#     'previous': 11.31,
#     'forecast': -6.45,
#     'actualRaw': 10440000000,
#     'previousRaw': 11310000000,
#     'forecastRaw': -6450000000,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-02-16T13:30:00.000Z'},
#    {'id': '348579',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Jan',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 8.88,
#     'previous': 10.8,
#     'forecast': 2.05,
#     'actualRaw': 8880000000,
#     'previousRaw': 10800000000,
#     'forecastRaw': 2049999999.9999998,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-03-15T12:30:00.000Z'},
#    {'id': '349965',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Feb',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': -8.78,
#     'previous': 8.88,
#     'forecast': 10.1,
#     'actualRaw': -8780000000,
#     'previousRaw': 8880000000,
#     'forecastRaw': 10100000000,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-04-17T12:30:00.000Z'},
#    {'id': '351553',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Mar',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 14.37,
#     'previous': -4.28,
#     'forecast': 3.51,
#     'actualRaw': 14370000000,
#     'previousRaw': -4280000000.0000005,
#     'forecastRaw': 3510000000,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-05-17T12:30:00.000Z'},
#    {'id': '353072',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Apr',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 41.16,
#     'previous': 14.38,
#     'forecast': 12.3,
#     'actualRaw': 41160000000,
#     'previousRaw': 14380000000,
#     'forecastRaw': 12300000000,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-06-17T12:30:00.000Z'},
#    {'id': '354483',
#     'title': 'Foreign Securities Purchases',
#     'country': 'CA',
#     'indicator': 'Foreign Stock Investment',
#     'ticker': 'ECONOMICS:CAFSI',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'May',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': None,
#     'previous': 41.16,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': 41160000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-07-17T12:30:00.000Z'}]},
#  {'id': '353073',
#   'title': 'Foreign Securities Purchases by Canadians',
#   'country': 'CA',
#   'indicator': 'Investment In Foreign Securities',
#   'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#   'category': 'mny',
#   'period': 'Apr',
#   'source': 'Statistics Canada',
#   'source_url': 'https://www.statcan.gc.ca',
#   'actual': 0,
#   'previous': 35.61,
#   'forecast': None,
#   'actualRaw': 0,
#   'previousRaw': 35610000000,
#   'forecastRaw': None,
#   'currency': 'CAD',
#   'unit': 'C$',
#   'scale': 'B',
#   'importance': -1,
#   'date': '2024-06-17T12:30:00.000Z',
#   'events': [{'id': '329109',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Aug',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 14.94,
#     'previous': 5.12,
#     'forecast': None,
#     'actualRaw': 14940000000,
#     'previousRaw': 5120000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2023-10-17T12:30:00.000Z'},
#    {'id': '330785',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Sep',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 11.6,
#     'previous': 14.75,
#     'forecast': None,
#     'actualRaw': 11600000000,
#     'previousRaw': 14750000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2023-11-17T13:30:00.000Z'},
#    {'id': '332356',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Oct',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': -8.2,
#     'previous': 9.6,
#     'forecast': None,
#     'actualRaw': -8199999999.999999,
#     'previousRaw': 9600000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2023-12-15T13:30:00.000Z'},
#    {'id': '345515',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Nov',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 12.53,
#     'previous': -8.2,
#     'forecast': None,
#     'actualRaw': 12530000000,
#     'previousRaw': -8199999999.999999,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-01-17T13:30:00.000Z'},
#    {'id': '347035',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Dec',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 29.4,
#     'previous': 12.38,
#     'forecast': None,
#     'actualRaw': 29400000000,
#     'previousRaw': 12380000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-02-16T13:30:00.000Z'},
#    {'id': '348577',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Jan',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': -7.59,
#     'previous': 29.4,
#     'forecast': None,
#     'actualRaw': -7590000000,
#     'previousRaw': 29400000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-03-15T12:30:00.000Z'},
#    {'id': '349964',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Feb',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 24.19,
#     'previous': -7.61,
#     'forecast': None,
#     'actualRaw': 24190000000,
#     'previousRaw': -7610000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-04-17T12:30:00.000Z'},
#    {'id': '351551',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Mar',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 35.61,
#     'previous': 24.16,
#     'forecast': None,
#     'actualRaw': 35610000000,
#     'previousRaw': 24160000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-05-17T12:30:00.000Z'},
#    {'id': '353073',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'Apr',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': 0,
#     'previous': 35.61,
#     'forecast': None,
#     'actualRaw': 0,
#     'previousRaw': 35610000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-06-17T12:30:00.000Z'},
#    {'id': '354482',
#     'title': 'Foreign Securities Purchases by Canadians',
#     'country': 'CA',
#     'indicator': 'Investment In Foreign Securities',
#     'comment': 'In Canada, the data series on international transactions in securities covers portfolio transactions in equity and investment fund shares, bonds and money market instruments for both Canadian and foreign issues. This activity excludes transactions in equity and debt instruments between affiliated enterprises, which are classified as foreign direct investment in international accounts.',
#     'category': 'mny',
#     'period': 'May',
#     'source': 'Statistics Canada',
#     'source_url': 'https://www.statcan.gc.ca',
#     'actual': None,
#     'previous': 0.02,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': 20000000,
#     'forecastRaw': None,
#     'currency': 'CAD',
#     'unit': 'C$',
#     'scale': 'B',
#     'importance': -1,
#     'date': '2024-07-17T12:30:00.000Z'}]},
#  {'id': '343291',
#   'title': '6-Month Bill Auction',
#   'country': 'US',
#   'indicator': '6 Month Bill Yield',
#   'category': 'bnd',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.treasurydirect.gov',
#   'actual': 5.15,
#   'previous': 5.165,
#   'forecast': None,
#   'actualRaw': 5.15,
#   'previousRaw': 5.165,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-17T15:30:00.000Z',
#   'events': [{'id': '342865',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.16,
#     'previous': 5.155,
#     'forecast': None,
#     'actualRaw': 5.16,
#     'previousRaw': 5.155,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-04-22T15:30:00.000Z'},
#    {'id': '342910',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.165,
#     'previous': 5.16,
#     'forecast': None,
#     'actualRaw': 5.165,
#     'previousRaw': 5.16,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-04-29T15:30:00.000Z'},
#    {'id': '342996',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.155,
#     'previous': 5.165,
#     'forecast': None,
#     'actualRaw': 5.155,
#     'previousRaw': 5.165,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-05-06T15:30:00.000Z'},
#    {'id': '343037',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.165,
#     'previous': 5.155,
#     'forecast': None,
#     'actualRaw': 5.165,
#     'previousRaw': 5.155,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-05-13T15:30:00.000Z'},
#    {'id': '343078',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.16,
#     'previous': 5.165,
#     'forecast': None,
#     'actualRaw': 5.16,
#     'previousRaw': 5.165,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-05-20T15:30:00.000Z'},
#    {'id': '343123',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.17,
#     'previous': 5.16,
#     'forecast': None,
#     'actualRaw': 5.17,
#     'previousRaw': 5.16,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-05-28T14:00:00.000Z'},
#    {'id': '343187',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.155,
#     'previous': 5.17,
#     'forecast': None,
#     'actualRaw': 5.155,
#     'previousRaw': 5.17,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-06-03T15:30:00.000Z'},
#    {'id': '343250',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.165,
#     'previous': 5.155,
#     'forecast': None,
#     'actualRaw': 5.165,
#     'previousRaw': 5.155,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-06-10T15:30:00.000Z'},
#    {'id': '343291',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
#     'category': 'bnd',
#     'period': '',
#     'source': 'Federal Reserve',
#     'source_url': 'http://www.treasurydirect.gov',
#     'actual': 5.15,
#     'previous': 5.165,
#     'forecast': None,
#     'actualRaw': 5.15,
#     'previousRaw': 5.165,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'unit': '%',
#     'importance': -1,
#     'date': '2024-06-17T15:30:00.000Z'},
#    {'id': '343331',
#     'title': '6-Month Bill Auction',
#     'country': 'US',
#     'indicator': '6 Month Bill Yield',
# ...
#   'previous': 488,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 488,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-21T17:00:00.000Z',
#   'events': [{'id': '342904',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Apr/26',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 506,
#     'previous': 511,
#     'forecast': None,
#     'actualRaw': 506,
#     'previousRaw': 511,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-04-26T17:00:00.000Z'},
#    {'id': '342978',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'May/03',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 499,
#     'previous': 506,
#     'forecast': None,
#     'actualRaw': 499,
#     'previousRaw': 506,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-03T17:00:00.000Z'},
#    {'id': '343032',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'May/10',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 496,
#     'previous': 499,
#     'forecast': None,
#     'actualRaw': 496,
#     'previousRaw': 499,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-10T17:00:00.000Z'},
#    {'id': '343073',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'May/17',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 497,
#     'previous': 496,
#     'forecast': None,
#     'actualRaw': 497,
#     'previousRaw': 496,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-17T17:00:00.000Z'},
#    {'id': '343117',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'May/24',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 497,
#     'previous': 497,
#     'forecast': None,
#     'actualRaw': 497,
#     'previousRaw': 497,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-24T17:00:00.000Z'},
#    {'id': '343154',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'May/31',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 496,
#     'previous': 497,
#     'forecast': None,
#     'actualRaw': 496,
#     'previousRaw': 497,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-31T17:00:00.000Z'},
#    {'id': '343244',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Jun/07',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 492,
#     'previous': 496,
#     'forecast': None,
#     'actualRaw': 492,
#     'previousRaw': 496,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-07T17:00:00.000Z'},
#    {'id': '343286',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Jun/14',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 488,
#     'previous': 492,
#     'forecast': None,
#     'actualRaw': 488,
#     'previousRaw': 492,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-14T17:00:00.000Z'},
#    {'id': '343325',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Jun/21',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': 488,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': 488,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-21T17:00:00.000Z'},
#    {'id': '343366',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Jun/28',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-28T17:00:00.000Z'},
#    {'id': '343457',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Jul/05',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-07-05T17:00:00.000Z'},
#    {'id': '343498',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Jul/12',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-07-12T17:00:00.000Z'},
#    {'id': '343538',
#     'title': 'Baker Hughes Oil Rig Count',
#     'country': 'US',
#     'indicator': 'Crude Oil Rigs',
#     'ticker': 'ECONOMICS:USCOR',
#     'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#     'period': 'Jul/19',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-07-19T17:00:00.000Z'}]},
#  {'id': '343326',
#   'title': 'Baker Hughes Total Rigs Count',
#   'country': 'US',
#   'indicator': 'Total Rigs',
#   'ticker': 'ECONOMICS:USTRG',
#   'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#   'period': 'Jun/21',
#   'source': 'Baker Hughes Company',
#   'source_url': 'https://www.bakerhughes.com/',
#   'actual': None,
#   'previous': 590,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 590,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-21T17:00:00.000Z',
#   'events': [{'id': '342905',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Apr/26',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 613,
#     'previous': 619,
#     'forecast': None,
#     'actualRaw': 613,
#     'previousRaw': 619,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-04-26T17:00:00.000Z'},
#    {'id': '342979',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'May/03',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 605,
#     'previous': 613,
#     'forecast': None,
#     'actualRaw': 605,
#     'previousRaw': 613,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-03T17:00:00.000Z'},
#    {'id': '343031',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'May/10',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 603,
#     'previous': 605,
#     'forecast': None,
#     'actualRaw': 603,
#     'previousRaw': 605,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-10T17:00:00.000Z'},
#    {'id': '343072',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'May/17',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 604,
#     'previous': 603,
#     'forecast': None,
#     'actualRaw': 604,
#     'previousRaw': 603,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-17T17:00:00.000Z'},
#    {'id': '343118',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'May/24',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 600,
#     'previous': 604,
#     'forecast': None,
#     'actualRaw': 600,
#     'previousRaw': 604,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-24T17:00:00.000Z'},
#    {'id': '343153',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'May/31',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 600,
#     'previous': 600,
#     'forecast': None,
#     'actualRaw': 600,
#     'previousRaw': 600,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-05-31T17:00:00.000Z'},
#    {'id': '343245',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Jun/07',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 594,
#     'previous': 600,
#     'forecast': None,
#     'actualRaw': 594,
#     'previousRaw': 600,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-07T17:00:00.000Z'},
#    {'id': '343285',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Jun/14',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': 590,
#     'previous': 594,
#     'forecast': None,
#     'actualRaw': 590,
#     'previousRaw': 594,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-14T17:00:00.000Z'},
#    {'id': '343326',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Jun/21',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': 590,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': 590,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-21T17:00:00.000Z'},
#    {'id': '343367',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Jun/28',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-06-28T17:00:00.000Z'},
#    {'id': '343458',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Jul/05',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-07-05T17:00:00.000Z'},
#    {'id': '343499',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Jul/12',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-07-12T17:00:00.000Z'},
#    {'id': '343539',
#     'title': 'Baker Hughes Total Rigs Count',
#     'country': 'US',
#     'indicator': 'Total Rigs',
#     'ticker': 'ECONOMICS:USTRG',
#     'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#     'period': 'Jul/19',
#     'source': 'Baker Hughes Company',
#     'source_url': 'https://www.bakerhughes.com/',
#     'actual': None,
#     'previous': None,
#     'forecast': None,
#     'actualRaw': None,
#     'previousRaw': None,
#     'forecastRaw': None,
#     'currency': 'USD',
#     'importance': -1,
#     'date': '2024-07-19T17:00:00.000Z'}]}]

# %%
import io
import logging
import subprocess
import sys
import warnings
from contextlib import suppress
from datetime import timedelta
from functools import reduce
from logging import StreamHandler
from os import chdir, getcwd, makedirs
from os.path import dirname, exists, join
from subprocess import CalledProcessError
from typing import List

import humanize
import numpy as np
import pandas as pd
import pandas_ta as ta
from google.cloud import bigquery
from moonshot.strategies.base import Moonshot
from numpy import nan
from pandas.testing import assert_frame_equal, assert_series_equal

if exists('/src'):
    WORKING_DIR = '/src'
else:
    with suppress(CalledProcessError):
        WORKING_DIR = subprocess.check_output(['git', 'rev-parse', '--show-toplevel']).strip().decode()
        sys.path.extend([WORKING_DIR,
                         join(WORKING_DIR, 'src'),
                         join(WORKING_DIR, 'notebook'),
                         join(WORKING_DIR, 'notebook/*')])
        
        WORKING_DIR = join(WORKING_DIR, 'src')


warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.8f}'.format

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
logger.addHandler(StreamHandler())

# %%
from data_providers.data_provider import DataProvider
from data_providers.tradingview_provider import TradingViewProvider

GCLOUD_PROJECT = 'trading-strategy-develop'
REGION = 'asia-southeast1'

# %set_env GCLOUD_PROJECT = $GCLOUD_PROJECT
# %set_env REGION = $REGION
# Out:
# env: GCLOUD_PROJECT=trading-strategy-develop
# env: REGION=asia-southeast1

# %%
provider: DataProvider = TradingViewProvider()
provider.WORKERS_NO = 4

# %%
results = provider.economic_calendar('2024-06-16', '2024-06-23')

# %%
results
# Out:
# [{'id': '352975',
#   'title': 'NY Empire State Manufacturing Index',
#   'country': 'US',
#   'indicator': 'Ny Empire State Manufacturing Index',
#   'ticker': 'ECONOMICS:USNYESMI',
#   'comment': 'New York Empire State Manufacturing Index is based on data compiled from the survey of 200 executives from the companies in the manufacturing sector in the New York State. Participants report the change in 11 indicators including level of general business activity, new orders, shipments, inventories, number of employees, delivery time, capital expenditure from the previous month and the likely direction of these indicators in six months. A reading above 0 indicates manufacturing activity is expanding, below 0 is contracting.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of New York',
#   'source_url': 'https://www.newyorkfed.org',
#   'actual': -6,
#   'previous': -15.6,
#   'forecast': -9,
#   'actualRaw': -6,
#   'previousRaw': -15.6,
#   'forecastRaw': -9,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-17T12:30:00.000Z'},
#  {'id': '343291',
#   'title': '6-Month Bill Auction',
#   'country': 'US',
#   'indicator': '6 Month Bill Yield',
#   'category': 'bnd',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.treasurydirect.gov',
#   'actual': 5.15,
#   'previous': 5.165,
#   'forecast': None,
#   'actualRaw': 5.15,
#   'previousRaw': 5.165,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-17T15:30:00.000Z'},
#  {'id': '343292',
#   'title': '3-Month Bill Auction',
#   'country': 'US',
#   'indicator': '3 Month Bill Yield',
#   'category': 'bnd',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.treasurydirect.gov',
#   'actual': 5.25,
#   'previous': 5.25,
#   'forecast': None,
#   'actualRaw': 5.25,
#   'previousRaw': 5.25,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-17T15:30:00.000Z'},
#  {'id': '364414',
#   'title': 'NOPA Crush Report',
#   'country': 'US',
#   'indicator': 'Calendar',
#   'category': 'gov',
#   'period': '',
#   'source': '',
#   'source_url': '',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-17T16:00:00.000Z'},
#  {'id': '365818',
#   'title': 'Fed Harker Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-17T17:00:00.000Z'},
#  {'id': '365874',
#   'title': '42-Day Bill Auction',
#   'country': 'US',
#   'indicator': 'Calendar',
#   'category': 'gov',
#   'period': '',
#   'source': '',
#   'source_url': '',
#   'actual': 5.27,
#   'previous': 5.27,
#   'forecast': None,
#   'actualRaw': 5.27,
#   'previousRaw': 5.27,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-17T17:00:00.000Z'},
#  {'id': '365860',
#   'title': 'Fed Cook Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-18T01:00:00.000Z'},
#  {'id': '352970',
#   'title': 'Retail Sales Ex Gas/Autos MoM',
#   'country': 'US',
#   'indicator': 'Retail Sales Ex Gas and Autos MoM',
#   'ticker': 'ECONOMICS:USRSEGAMM',
#   'comment': 'Retail Sales Ex Gas and Autos in the US provides aggregated measure of sales of retail goods and services excluding motor vehicle dealers and gasoline station over a period of a month.',
#   'category': 'cnsm',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'http://www.census.gov',
#   'actual': None,
#   'previous': -0.1,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -0.1,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T12:30:00.000Z'},
#  {'id': '352976',
#   'title': 'Retail Sales YoY',
#   'country': 'US',
#   'indicator': 'Retail Sales YoY',
#   'ticker': 'ECONOMICS:USRSYY',
#   'comment': 'In the United States, the year-over-year change in Retail sales compares the aggregated sales of retail goods and services during a certain month to the same month a year ago.',
#   'category': 'cnsm',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'http://www.census.gov',
#   'actual': None,
#   'previous': 3,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 3,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T12:30:00.000Z'},
#  {'id': '352977',
#   'title': 'Retail Sales Ex Autos MoM',
#   'country': 'US',
#   'indicator': 'Retail Sales Ex Autos',
#   'ticker': 'ECONOMICS:USRSEA',
#   'comment': 'Retail Sales Ex Autos report in the US provides aggregated measure of sales of retail goods and services excluding the automobile sector over a period of a month.',
#   'category': 'cnsm',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'http://www.census.gov',
#   'actual': None,
#   'previous': 0.2,
#   'forecast': 0.2,
#   'actualRaw': None,
#   'previousRaw': 0.2,
#   'forecastRaw': 0.2,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': 0,
#   'date': '2024-06-18T12:30:00.000Z'},
#  {'id': '352978',
#   'title': 'Retail Sales MoM',
#   'country': 'US',
#   'indicator': 'Retail Sales MoM',
#   'ticker': 'ECONOMICS:USRSMM',
#   'comment': 'Retail sales report in the US provides aggregated measure of sales of retail goods and services over a period of a month. There are thirteen major types of retailers: Motor vehicle & parts dealers (around 20 percent of total sales), Food & beverage stores (13%), General merchandise stores (12.5%), Food services & drinking places (11%), Gasoline stations (10%), Nonstore retailers (9.2%), Building material & garden dealers (6%), Health & personal care stores (6%), Clothing & clothing accessories stores (5%), Miscellaneous store retailers (2.3%), Furniture stores (2%), Electronics & appliance stores (2%) and Sporting goods, hobby, book & music stores (1.7%).',
#   'category': 'cnsm',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'https://www.census.gov/',
#   'actual': None,
#   'previous': 0,
#   'forecast': 0.2,
#   'actualRaw': None,
#   'previousRaw': 0,
#   'forecastRaw': 0.2,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': 1,
#   'date': '2024-06-18T12:30:00.000Z'},
#  {'id': '343293',
#   'title': 'Redbook YoY',
#   'country': 'US',
#   'indicator': 'Redbook Index',
#   'ticker': 'ECONOMICS:USRI',
#   'comment': "The Johnson Redbook Index is a sales-weighted of year-over-year same-store sales growth in a sample of large US general merchandise retailers representing about 9,000 stores. Same-store sales are sales in stores continuously open for 12 months or longer. By dollar value, the Index represents over 80% of the equivalent 'official' retail sales series collected and published by the US Department of Commerce. Redbook compiles the Index by collecting and interpreting performance estimates from retailers. The Index and its sub-groups are sales-weighted aggregates of these estimates. Weeks are retail weeks (Sunday to Saturday), and equally weighted within the month.",
#   'category': 'cnsm',
#   'period': 'Jun/15',
#   'source': 'Redbook Research Inc.',
#   'source_url': 'http://www.redbookresearch.com/',
#   'actual': None,
#   'previous': 5.5,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 5.5,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T12:55:00.000Z'},
#  {'id': '352994',
#   'title': 'Capacity Utilization',
#   'country': 'US',
#   'indicator': 'Capacity Utilization',
#   'ticker': 'ECONOMICS:USCU',
#   'comment': 'Capacity utilization rate is used to measure the rate at which potential output levels are being met or used. The capacity indexes cover all facilities located in the United States, regardless of their ownership; and are constructed for 89 detailed industries (71 in manufacturing, 16 in mining, and 2 in utilities).',
#   'category': 'bsnss',
#   'period': 'May',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov',
#   'actual': None,
#   'previous': 78.4,
#   'forecast': 78.6,
#   'actualRaw': None,
#   'previousRaw': 78.4,
#   'forecastRaw': 78.6,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T13:15:00.000Z'},
#  {'id': '352995',
#   'title': 'Manufacturing Production YoY',
#   'country': 'US',
#   'indicator': 'Manufacturing Production',
#   'ticker': 'ECONOMICS:USMPRYY',
#   'comment': 'Manufacturing production measures the output of businesses operating in the manufacturing sector. It is the most important sector and accounts for 78 percent of total production. The biggest segments within the sector are: Chemicals (12 percent of total production); food, drink and tobacco (11 percent); machinery (6 percent); fabricated metal products (6 percent); computer and electronic products (6 percent); and motor vehicles and parts (6 percent).',
#   'category': 'bsnss',
#   'period': 'May',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov',
#   'actual': None,
#   'previous': -0.5,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -0.5,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T13:15:00.000Z'},
#  {'id': '352996',
#   'title': 'Industrial Production YoY',
#   'country': 'US',
#   'indicator': 'Industrial Production',
#   'ticker': 'ECONOMICS:USIPYY',
#   'comment': 'In the United States, industrial production measures the output of businesses integrated in industrial sector of the economy. Manufacturing is the most important sector and accounts for 78 percent of total production. The biggest segments within Manufacturing are: Chemicals (12 percent of total production); food, drink and tobacco (11 percent); machinery (6 percent); fabricated metal products (6 percent); computer and electronic products (6 percent); and motor vehicles and parts (6 percent). Mining and quarrying account for 11 percent of production and utilities account for the remaining 11 percent.',
#   'category': 'bsnss',
#   'period': 'May',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov',
#   'actual': None,
#   'previous': -0.4,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -0.4,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T13:15:00.000Z'},
#  {'id': '352997',
#   'title': 'Industrial Production MoM',
#   'country': 'US',
#   'indicator': 'Industrial Production Mom',
#   'ticker': 'ECONOMICS:USIPMM',
#   'comment': 'In the United States, industrial production measures the output of businesses integrated in industrial sector of the economy. Manufacturing is the most important sector and accounts for 78 percent of total production. The biggest segments within Manufacturing are: Chemicals (12 percent of total production); food, drink and tobacco (11 percent); machinery (6 percent); fabricated metal products (6 percent); computer and electronic products (6 percent); and motor vehicles and parts (6 percent). Mining and quarrying account for 11 percent of production and utilities account for the remaining 11 percent.',
#   'category': 'bsnss',
#   'period': 'May',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov',
#   'actual': None,
#   'previous': 0,
#   'forecast': 0.3,
#   'actualRaw': None,
#   'previousRaw': 0,
#   'forecastRaw': 0.3,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': 0,
#   'date': '2024-06-18T13:15:00.000Z'},
#  {'id': '352998',
#   'title': 'Manufacturing Production MoM',
#   'country': 'US',
#   'indicator': 'Manufacturing Production MoM',
#   'ticker': 'ECONOMICS:USMPRMM',
#   'comment': 'Manufacturing production measures the output of businesses operating in the manufacturing sector. It is the most important sector and accounts for 78 percent of total production. The biggest segments within the sector are: Chemicals (12 percent of total production); food, drink and tobacco (11 percent); machinery (6 percent); fabricated metal products (6 percent); computer and electronic products (6 percent); and motor vehicles and parts (6 percent).',
#   'category': 'bsnss',
#   'period': 'May',
#   'source': 'Federal Reserve',
#   'source_url': 'https://www.federalreserve.gov/default.htm',
#   'actual': None,
#   'previous': -0.3,
#   'forecast': 0.3,
#   'actualRaw': None,
#   'previousRaw': -0.3,
#   'forecastRaw': 0.3,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T13:15:00.000Z'},
#  {'id': '353000',
#   'title': 'Retail Inventories Ex Autos MoM',
#   'country': 'US',
#   'indicator': 'Retail Inventories Ex Autos',
#   'ticker': 'ECONOMICS:USRIEA',
#   'category': 'bsnss',
#   'period': 'Apr',
#   'source': 'Census Bureau',
#   'source_url': 'https://www.census.gov/',
#   'actual': None,
#   'previous': -0.2,
#   'forecast': 0.3,
#   'actualRaw': None,
#   'previousRaw': -0.2,
#   'forecastRaw': 0.3,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T14:00:00.000Z'},
#  {'id': '353001',
#   'title': 'Business Inventories MoM',
#   'country': 'US',
#   'indicator': 'Business Inventories',
#   'ticker': 'ECONOMICS:USBI',
#   'comment': 'Business Inventories in the United States measure the monthly percentage changes in inventories from manufacturers, retailers, and wholesalers. Inventories are a key component of gross domestic product.',
#   'category': 'bsnss',
#   'period': 'Apr',
#   'source': 'Census Bureau',
#   'source_url': 'https://www.census.gov',
#   'actual': None,
#   'previous': -0.1,
#   'forecast': 0.3,
#   'actualRaw': None,
#   'previousRaw': -0.1,
#   'forecastRaw': 0.3,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': 0,
#   'date': '2024-06-18T14:00:00.000Z'},
#  {'id': '365866',
#   'title': 'Fed Barkin Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-18T14:00:00.000Z'},
#  {'id': '365871',
#   'title': 'NY Fed Treasury Purchases 0 to 1 yrs',
#   'country': 'US',
#   'indicator': 'Calendar',
#   'category': 'gov',
#   'period': '',
#   'source': '',
#   'source_url': '',
#   'actual': None,
#   'previous': None,
#   'forecast': 80,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-18T14:30:00.000Z'},
#  {'id': '365867',
#   'title': 'Fed Collins Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-18T15:40:00.000Z'},
#  {'id': '365261',
#   'title': '20-Year Bond Auction',
#   'country': 'US',
#   'indicator': '20 Year Bond Yield',
#   'category': 'bnd',
#   'period': '',
#   'source': '',
#   'source_url': '',
#   'actual': None,
#   'previous': 4.635,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 4.635,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-18T17:00:00.000Z'},
#  {'id': '365861',
#   'title': 'Fed Kugler Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-18T17:00:00.000Z'},
#  {'id': '365868',
#   'title': 'Fed Logan Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-18T17:00:00.000Z'},
#  {'id': '365869',
#   'title': 'Fed Musalem Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-18T17:20:00.000Z'},
#  {'id': '365819',
#   'title': 'Fed Goolsbee Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-18T18:00:00.000Z'},
#  {'id': '353013',
#   'title': 'Foreign Bond Investment',
#   'country': 'US',
#   'indicator': 'Foreign Bond Investment',
#   'ticker': 'ECONOMICS:USFBI',
#   'comment': 'Foreign Bond Investment refers to net purchases of US treasury bonds and notes by foreign individuals or companies. Negative figures indicate net sales by foreigners to US residents or a net outflow of capital from the United States.\n.',
#   'category': 'mny',
#   'period': 'Apr',
#   'source': 'Department of the Treasury',
#   'source_url': 'https://www.treasury.gov',
#   'actual': None,
#   'previous': 42.2,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 42200000000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '$',
#   'scale': 'B',
#   'importance': -1,
#   'date': '2024-06-18T20:00:00.000Z'},
#  {'id': '353014',
#   'title': 'Net Long-term TIC Flows',
#   'country': 'US',
#   'indicator': 'Net Long-term TIC Flows',
#   'ticker': 'ECONOMICS:USTICNLF',
#   'comment': 'The Net Long-Term TIC Flows track the flow of Treasury and agency securities, corporate bonds and equities, into and out of the United States.',
#   'category': 'trd',
#   'period': 'Apr',
#   'source': 'Department of the Treasury',
#   'source_url': 'https://home.treasury.gov/',
#   'actual': None,
#   'previous': 100.5,
#   'forecast': 69,
#   'actualRaw': None,
#   'previousRaw': 100500000000,
#   'forecastRaw': 69000000000,
#   'currency': 'USD',
#   'unit': '$',
#   'scale': 'B',
#   'importance': 0,
#   'date': '2024-06-18T20:00:00.000Z'},
#  {'id': '353015',
#   'title': 'Overall Net Capital Flows',
#   'country': 'US',
#   'indicator': 'Capital Flows',
#   'ticker': 'ECONOMICS:USCF',
#   'comment': 'Net Treasury International Capital Flows includes all net foreign acquisitions of long-term securities, short-term U.S. securities, and banking flows.',
#   'category': 'trd',
#   'period': 'Apr',
#   'source': 'Department of the Treasury',
#   'source_url': 'https://home.treasury.gov/',
#   'actual': None,
#   'previous': 102.1,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 102100000000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '$',
#   'scale': 'B',
#   'importance': -1,
#   'date': '2024-06-18T20:00:00.000Z'},
#  {'id': '343295',
#   'title': 'API Crude Oil Stock Change',
#   'country': 'US',
#   'indicator': 'API Crude Oil Stock Change',
#   'ticker': 'ECONOMICS:USCSC',
#   'comment': 'Stocks of crude oil refer to the weekly change of the crude oil supply situation.',
#   'period': 'Jun/14',
#   'source': 'American Petroleum Institute (API)',
#   'source_url': 'http://www.api.org',
#   'actual': None,
#   'previous': -2.428,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -2428000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': 0,
#   'date': '2024-06-18T20:30:00.000Z'},
#  {'id': '341928',
#   'title': 'Juneteenth National Independence Day',
#   'country': 'US',
#   'indicator': 'Holidays',
#   'category': 'gov',
#   'period': '',
#   'source': '',
#   'source_url': '',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-19T00:00:00.000Z'},
#  {'id': '353098',
#   'title': 'NAHB Housing Market Index',
#   'country': 'US',
#   'indicator': 'Nahb Housing Market Index',
#   'ticker': 'ECONOMICS:USHMI',
#   'comment': 'NAHB/Wells Fargo Housing Market Index (HMI) is based on a monthly survey of home builders. They are asked to rate current sales of single-family homes and sales expectations for the next six months and to rate traffic of prospective buyers. Scores for responses to each component are used to calculate a seasonally adjusted overall index, where a number over 50 indicates more builders view sales conditions as good than poor.',
#   'category': 'hse',
#   'period': 'Jun',
#   'source': 'National Association of Home Builders',
#   'source_url': 'https://www.nahb.org',
#   'actual': None,
#   'previous': 45,
#   'forecast': 45,
#   'actualRaw': None,
#   'previousRaw': 45,
#   'forecastRaw': 45,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-19T14:00:00.000Z'},
#  {'id': '353155',
#   'title': 'International Monetary Market (IMM) Date',
#   'country': 'US',
#   'indicator': 'Calendar',
#   'category': 'gov',
#   'period': '',
#   'source': '',
#   'source_url': '',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T00:00:00.000Z'},
#  {'id': '343296',
#   'title': 'MBA Purchase Index',
#   'country': 'US',
#   'indicator': 'MBA Purchase Index',
#   'ticker': 'ECONOMICS:USPIND',
#   'category': 'hse',
#   'period': 'Jun/14',
#   'source': 'Mortgage Bankers Association of America',
#   'source_url': 'http://www.mortgagebankers.org/',
#   'actual': None,
#   'previous': 143.7,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 143.7,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T11:00:00.000Z'},
#  {'id': '343297',
#   'title': 'MBA Mortgage Applications',
#   'country': 'US',
#   'indicator': 'Mortgage Applications',
#   'ticker': 'ECONOMICS:USMAPL',
#   'comment': 'In the US, the MBA Weekly Mortgage Application Survey is a comprehensive overview of the nationwide mortgage market and covers all types of mortgage originators, including commercial banks, thrift institutions and mortgage banking companies. The entire market is represented by the Market Index which covers all mortgage applications during the week, whether for a purchase or to refinance. The survey covers over 75% of all US retail residential mortgage applications.',
#   'category': 'hse',
#   'period': 'Jun/14',
#   'source': 'Mortgage Bankers Association of America',
#   'source_url': 'http://www.mortgagebankers.org/',
#   'actual': None,
#   'previous': 15.6,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 15.6,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T11:00:00.000Z'},
#  {'id': '343298',
#   'title': 'MBA Mortgage Market Index',
#   'country': 'US',
#   'indicator': 'MBA Mortgage Market Index',
#   'ticker': 'ECONOMICS:USMMI',
#   'comment': 'The MBA Weekly Mortgage Application Survey is a comprehensive overview of the nationwide mortgage market and covers all types of mortgage originators, including commercial banks, thrift institutions and mortgage banking companies. The entire market is represented by the Market Index which covers all mortgage applications during the week. This includes all conventional and government applications, all fixed-rate mortgages (FRMs), all adjustable-rate mortgages (ARMs), whether for a purchase or to refinance.',
#   'category': 'hse',
#   'period': 'Jun/14',
#   'source': 'Mortgage Bankers Association of America',
#   'source_url': 'http://www.mortgagebankers.org/',
#   'actual': None,
#   'previous': 208.5,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 208.5,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T11:00:00.000Z'},
#  {'id': '343299',
#   'title': 'MBA 30-Year Mortgage Rate',
#   'country': 'US',
#   'indicator': 'Mortgage Rate',
#   'ticker': 'ECONOMICS:USMR',
#   'comment': 'MBA 30-Year Mortgage Rate is average 30-year fixed mortgage lending rate\xa0measured during the reported week and backed by the Mortgage Bankers Association.',
#   'category': 'hse',
#   'period': 'Jun/14',
#   'source': 'Mortgage Bankers Association of America',
#   'source_url': 'http://www.mortgagebankers.org/',
#   'actual': None,
#   'previous': 7.02,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 7.02,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T11:00:00.000Z'},
#  {'id': '343300',
#   'title': 'MBA Mortgage Refinance Index',
#   'country': 'US',
#   'indicator': 'MBA Mortgage Refinance Index',
#   'ticker': 'ECONOMICS:USMRI',
#   'comment': 'The MBA Weekly Mortgage Application Survey is a comprehensive overview of the nationwide mortgage market and covers all types of mortgage originators, including commercial banks, thrift institutions and mortgage banking companies. The entire market is represented by the Market Index which covers all mortgage applications during the week. This includes all conventional and government applications, all fixed-rate mortgages (FRMs), all adjustable-rate mortgages (ARMs), whether for a purchase or to refinance.',
#   'category': 'hse',
#   'period': 'Jun/14',
#   'source': 'Mortgage Bankers Association of America',
#   'source_url': 'http://www.mortgagebankers.org/',
#   'actual': None,
#   'previous': 554.7,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 554.7,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T11:00:00.000Z'},
#  {'id': '343314',
#   'title': 'Continuing Jobless Claims',
#   'country': 'US',
#   'indicator': 'Continuing Jobless Claims',
#   'ticker': 'ECONOMICS:USCJC',
#   'comment': 'Continuing Jobless Claims refer to actual number of unemployed and currently receiving unemployment benefits who filed for unemployment benefits at least two weeks ago.',
#   'category': 'lbr',
#   'period': 'Jun/08',
#   'source': 'Department of Labour',
#   'source_url': 'http://www.dol.gov',
#   'actual': None,
#   'previous': 1820,
#   'forecast': 1810,
#   'actualRaw': None,
#   'previousRaw': 1820000,
#   'forecastRaw': 1810000,
#   'currency': 'USD',
#   'scale': 'K',
#   'importance': -1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '343315',
#   'title': 'Initial Jobless Claims',
#   'country': 'US',
#   'indicator': 'Initial Jobless Claims',
#   'ticker': 'ECONOMICS:USIJC',
#   'comment': "Initial jobless claims refer to the number of people who have filed for unemployment benefits with their state's unemployment agency for the first time during a specific reporting period, typically on a weekly basis. \n.",
#   'category': 'lbr',
#   'period': 'Jun/15',
#   'source': 'Department of Labour',
#   'source_url': 'http://www.dol.gov',
#   'actual': None,
#   'previous': 242,
#   'forecast': 235,
#   'actualRaw': None,
#   'previousRaw': 242000,
#   'forecastRaw': 235000,
#   'currency': 'USD',
#   'scale': 'K',
#   'importance': 0,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '343316',
#   'title': 'Jobless Claims 4-week Average',
#   'country': 'US',
#   'indicator': 'Jobless Claims 4-week Average',
#   'ticker': 'ECONOMICS:USJC4W',
#   'category': 'lbr',
#   'period': 'Jun/15',
#   'source': 'Department of Labour',
#   'source_url': 'http://www.dol.gov',
#   'actual': None,
#   'previous': 227,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 227000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'K',
#   'importance': -1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '352980',
#   'title': 'Philly Fed Business Conditions',
#   'country': 'US',
#   'indicator': 'Philly Fed Business Conditions',
#   'ticker': 'ECONOMICS:USPHFBCOND',
#   'comment': 'Philadelphia Fed Manufacturing Index is based on The Business Outlook Survey of manufacturers in the Third Federal Reserve District. Participants report the direction of change in overall business activity and in the various measures of activity at their plants: employment, working hours, new and unfilled orders, shipments, inventories, delivery times, prices paid, and prices received. The index above 0 indicates factory-sector growth, below 0 contraction.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of Philadelphia',
#   'source_url': 'https://www.philadelphiafed.org/',
#   'actual': None,
#   'previous': 32.4,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 32.4,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '352981',
#   'title': 'Philly Fed Employment',
#   'country': 'US',
#   'indicator': 'Philly Fed Employment',
#   'ticker': 'ECONOMICS:USPHFEMP',
#   'comment': 'Philadelphia Fed Manufacturing Index is based on The Business Outlook Survey of manufacturers in the Third Federal Reserve District. Participants report the direction of change in overall business activity and in the various measures of activity at their plants: employment, working hours, new and unfilled orders, shipments, inventories, delivery times, prices paid, and prices received. The index above 0 indicates factory-sector growth, below 0 contraction.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of Philadelphia',
#   'source_url': 'https://www.philadelphiafed.org/',
#   'actual': None,
#   'previous': -7.9,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -7.9,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '352982',
#   'title': 'Philly Fed CAPEX Index',
#   'country': 'US',
#   'indicator': 'Philly Fed CAPEX Index',
#   'ticker': 'ECONOMICS:USPHFCAPEX',
#   'comment': 'Philadelphia Fed Manufacturing Index is based on The Business Outlook Survey of manufacturers in the Third Federal Reserve District. Participants report the direction of change in overall business activity and in the various measures of activity at their plants: employment, working hours, new and unfilled orders, shipments, inventories, delivery times, prices paid, and prices received. The index above 0 indicates factory-sector growth, below 0 contraction.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of Philadelphia',
#   'source_url': 'https://www.philadelphiafed.org/',
#   'actual': None,
#   'previous': 20.1,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 20.1,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '352983',
#   'title': 'Philly Fed New Orders',
#   'country': 'US',
#   'indicator': 'Philly Fed New Orders',
#   'ticker': 'ECONOMICS:USPHFNORD',
#   'comment': 'Philadelphia Fed Manufacturing Index is based on The Business Outlook Survey of manufacturers in the Third Federal Reserve District. Participants report the direction of change in overall business activity and in the various measures of activity at their plants: employment, working hours, new and unfilled orders, shipments, inventories, delivery times, prices paid, and prices received. The index above 0 indicates factory-sector growth, below 0 contraction.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of Philadelphia',
#   'source_url': 'https://www.philadelphiafed.org/',
#   'actual': None,
#   'previous': -7.9,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -7.9,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '352984',
#   'title': 'Philadelphia Fed Manufacturing Index',
#   'country': 'US',
#   'indicator': 'Philadelphia Fed Manufacturing Index',
#   'ticker': 'ECONOMICS:USPFMI',
#   'comment': 'Philadelphia Fed Manufacturing Index is based on The Business Outlook Survey of manufacturers in the Third Federal Reserve District. Participants report the direction of change in overall business activity and in the various measures of activity at their plants: employment, working hours, new and unfilled orders, shipments, inventories, delivery times, prices paid, and prices received. The index above 0 indicates factory-sector growth, below 0 contraction.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of Philadelphia',
#   'source_url': 'https://www.philadelphiafed.org/',
#   'actual': None,
#   'previous': 4.5,
#   'forecast': 4.5,
#   'actualRaw': None,
#   'previousRaw': 4.5,
#   'forecastRaw': 4.5,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '352985',
#   'title': 'Philly Fed Prices Paid',
#   'country': 'US',
#   'indicator': 'Philly Fed Prices Paid',
#   'ticker': 'ECONOMICS:USPHFPP',
#   'comment': 'Philadelphia Fed Manufacturing Index is based on The Business Outlook Survey of manufacturers in the Third Federal Reserve District. Participants report the direction of change in overall business activity and in the various measures of activity at their plants: employment, working hours, new and unfilled orders, shipments, inventories, delivery times, prices paid, and prices received. The index above 0 indicates factory-sector growth, below 0 contraction.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'Federal Reserve Bank of Philadelphia',
#   'source_url': 'https://www.philadelphiafed.org/',
#   'actual': None,
#   'previous': 18.7,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 18.7,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '353145',
#   'title': 'Housing Starts',
#   'country': 'US',
#   'indicator': 'Housing Starts',
#   'ticker': 'ECONOMICS:USHST',
#   'comment': 'Housing Starts refer to the number of new residential construction projects that have begun during any particular month. Estimates of housing starts include units in structures being totally rebuilt on an existing foundation.',
#   'category': 'hse',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'https://www.census.gov/',
#   'actual': None,
#   'previous': 1.36,
#   'forecast': 1.38,
#   'actualRaw': None,
#   'previousRaw': 1360000,
#   'forecastRaw': 1380000,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': 0,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '353146',
#   'title': 'Housing Starts MoM',
#   'country': 'US',
#   'indicator': 'Housing Starts MoM',
#   'ticker': 'ECONOMICS:USHSTMM',
#   'comment': 'Housing Starts refer to the number of new residential construction projects that have begun during any particular month. Estimates of housing starts include units in structures being totally rebuilt on an existing foundation.',
#   'category': 'hse',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'https://www.census.gov/',
#   'actual': None,
#   'previous': 5.7,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 5.7,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': 0,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '353147',
#   'title': 'Building Permits Prel',
#   'country': 'US',
#   'indicator': 'Building Permits',
#   'ticker': 'ECONOMICS:USBP',
#   'comment': 'Building Permits refer to the approvals given by a local jurisdictions before the construction of a new or existing building can legally occur. Not all areas of the United States require a permit for construction.',
#   'category': 'hse',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'https://www.census.gov',
#   'actual': None,
#   'previous': 1.44,
#   'forecast': 1.45,
#   'actualRaw': None,
#   'previousRaw': 1440000,
#   'forecastRaw': 1450000,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': 1,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '353148',
#   'title': 'Building Permits MoM Prel',
#   'country': 'US',
#   'indicator': 'Building Permits MoM',
#   'ticker': 'ECONOMICS:USBPMM',
#   'comment': 'Building Permits refer to the approvals given by a local jurisdictions before the construction of a new or existing building can legally occur. Not all areas of the United States require a permit for construction.',
#   'category': 'hse',
#   'period': 'May',
#   'source': 'Census Bureau',
#   'source_url': 'https://www.census.gov',
#   'actual': None,
#   'previous': -3,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -3,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': 0,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '353237',
#   'title': 'Current Account',
#   'country': 'US',
#   'indicator': 'Current Account',
#   'ticker': 'ECONOMICS:USCA',
#   'comment': 'Current Account is the sum of the balance of trade (exports minus imports of goods and services), net factor income (such as interest and dividends) and net transfer payments (such as foreign aid).',
#   'category': 'trd',
#   'period': 'Q1',
#   'source': 'Bureau of Economics Analysis',
#   'source_url': 'http://www.bea.gov',
#   'actual': None,
#   'previous': -194.8,
#   'forecast': -206.8,
#   'actualRaw': None,
#   'previousRaw': -194800000000,
#   'forecastRaw': -206800000000,
#   'currency': 'USD',
#   'unit': '$',
#   'scale': 'B',
#   'importance': 0,
#   'date': '2024-06-20T12:30:00.000Z'},
#  {'id': '343302',
#   'title': 'EIA Heating Oil Stocks Change',
#   'country': 'US',
#   'indicator': 'Heating Oil Stocks',
#   'ticker': 'ECONOMICS:USHOS',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'https://www.eia.gov',
#   'actual': None,
#   'previous': -0.656,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -656000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': -1,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343303',
#   'title': 'EIA Refinery Crude Runs Change',
#   'country': 'US',
#   'indicator': 'Refinery Crude Runs',
#   'ticker': 'ECONOMICS:USRCR',
#   'comment': 'Crude Runs refer to the volume of crude oil consumed by refineries.',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'https://www.eia.gov',
#   'actual': None,
#   'previous': -0.097,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -97000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': -1,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343304',
#   'title': 'EIA Crude Oil Stocks Change',
#   'country': 'US',
#   'indicator': 'Crude Oil Stocks Change',
#   'ticker': 'ECONOMICS:USCOSC',
#   'comment': 'Stocks of crude oil refer to the weekly change of the crude oil supply situation.',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'https://www.eia.gov',
#   'actual': None,
#   'previous': 3.73,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 3730000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': 0,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343305',
#   'title': 'EIA Gasoline Stocks Change',
#   'country': 'US',
#   'indicator': 'Gasoline Stocks Change',
#   'ticker': 'ECONOMICS:USGSCH',
#   'comment': 'Stocks of gasoline refers to the weekly change of the gasoline supply situation.',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'http://www.eia.gov',
#   'actual': None,
#   'previous': 2.566,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 2566000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': 0,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343306',
#   'title': 'EIA Crude Oil Imports Change',
#   'country': 'US',
#   'indicator': 'Crude Oil Imports',
#   'ticker': 'ECONOMICS:USCOI',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'https://www.eia.gov',
#   'actual': None,
#   'previous': 2.559,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 2559000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': -1,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343307',
#   'title': 'EIA Distillate Fuel Production Change',
#   'country': 'US',
#   'indicator': 'Distillate Fuel Production',
#   'ticker': 'ECONOMICS:USDFP',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'https://www.eia.gov',
#   'actual': None,
#   'previous': -0.029,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -29000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': -1,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343308',
#   'title': 'EIA Distillate Stocks Change',
#   'country': 'US',
#   'indicator': 'Distillate Stocks',
#   'ticker': 'ECONOMICS:USDFS',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'https://www.eia.gov',
#   'actual': None,
#   'previous': 0.881,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 881000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': -1,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343309',
#   'title': 'EIA Cushing Crude Oil Stocks Change',
#   'country': 'US',
#   'indicator': 'Cushing Crude Oil Stocks',
#   'ticker': 'ECONOMICS:USCCOS',
#   'comment': 'Change in the number of barrels of crude oil held in storage at the Cushing, Oklahoma during the past week.',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'https://www.eia.gov',
#   'actual': None,
#   'previous': -1.593,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -1593000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': -1,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343310',
#   'title': 'EIA Gasoline Production Change',
#   'country': 'US',
#   'indicator': 'Gasoline Production',
#   'ticker': 'ECONOMICS:USGPRO',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'http://www.eia.gov',
#   'actual': None,
#   'previous': 0.602,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 602000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': -1,
#   'date': '2024-06-20T15:00:00.000Z'},
#  {'id': '343318',
#   'title': '4-Week Bill Auction',
#   'country': 'US',
#   'indicator': '4 Week Bill Yield',
#   'category': 'bnd',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'https://www.treasurydirect.gov',
#   'actual': None,
#   'previous': 5.26,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 5.26,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T15:30:00.000Z'},
#  {'id': '343319',
#   'title': '8-Week Bill Auction',
#   'country': 'US',
#   'indicator': '8 Week Bill Yield',
#   'category': 'bnd',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'https://www.treasurydirect.gov',
#   'actual': None,
#   'previous': 5.265,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 5.265,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T15:30:00.000Z'},
#  {'id': '365248',
#   'title': '17-Week Bill Auction',
#   'country': 'US',
#   'indicator': 'Calendar',
#   'category': 'gov',
#   'period': '',
#   'source': '',
#   'source_url': '',
#   'actual': None,
#   'previous': 5.22,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 5.22,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T15:30:00.000Z'},
#  {'id': '343320',
#   'title': '15-Year Mortgage Rate',
#   'country': 'US',
#   'indicator': '15 Year Mortgage Rate',
#   'category': 'hse',
#   'period': 'Jun/19',
#   'source': 'Freddie',
#   'source_url': 'https://www.freddiemac.com/',
#   'actual': None,
#   'previous': 6.17,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 6.17,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T16:00:00.000Z'},
#  {'id': '343321',
#   'title': '30-Year Mortgage Rate',
#   'country': 'US',
#   'indicator': '30 Year Mortgage Rate',
#   'ticker': 'ECONOMICS:US30YMR',
#   'comment': 'The Primary Mortgage Market Survey (PMMS) is focused on conventional, conforming, fully amortizing home purchase loans for borrowers who put 20 percent down and have excellent credit. Average commitment rates should be reported along with average fees and points to reflect the total upfront cost of obtaining the mortgage. The interest rate a lender would charge to lend mortgage money to a qualified borrower exclusive of the fees and points required by the lender. This commitment rate applies only to conventional financing on conforming mortgages with loan-to-value rates of 80 percent or less.',
#   'category': 'hse',
#   'period': 'Jun/19',
#   'source': 'Freddie',
#   'source_url': 'https://www.freddiemac.com/',
#   'actual': None,
#   'previous': 6.95,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 6.95,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T16:00:00.000Z'},
#  {'id': '365274',
#   'title': '5-Year TIPS Auction',
#   'country': 'US',
#   'indicator': '5 Year TIPS Yield',
#   'category': 'bnd',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'https://www.treasurydirect.gov',
#   'actual': None,
#   'previous': 2.242,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 2.242,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-20T17:00:00.000Z'},
#  {'id': '365820',
#   'title': 'Fed Barkin Speech',
#   'country': 'US',
#   'indicator': 'Interest Rate',
#   'ticker': 'ECONOMICS:USINTR',
#   'comment': 'In the United States, the authority to set interest rates is divided between the Board of Governors of the Federal Reserve (Board) and the Federal Open Market Committee (FOMC). The Board decides on changes in discount rates after recommendations submitted by one or more of the regional Federal Reserve Banks. The FOMC decides on open market operations, including the desired levels of central bank money or the desired federal funds market rate.',
#   'category': 'mny',
#   'period': '',
#   'source': 'Federal Reserve',
#   'source_url': 'http://www.federalreserve.gov/',
#   'actual': None,
#   'previous': None,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': None,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-20T20:00:00.000Z'},
#  {'id': '353331',
#   'title': 'S&P Global Manufacturing PMI Flash',
#   'country': 'US',
#   'indicator': 'Manufacturing PMI',
#   'ticker': 'ECONOMICS:USMPMI',
#   'comment': 'The S&P Global US Manufacturing PMI is compiled by S&P Global from responses to questionnaires sent to purchasing managers in a panel of around 800 manufacturers. The headline figure is the Purchasing Managers’ Index (PMI), which is a weighted average of the following five indices: New Orders (30%), Output (25%), Employment (20%), Suppliers’ Delivery Times (15%) and Stocks of Purchases (10%). For the PMI calculation the Suppliers’ Delivery Times Index is inverted so that it moves in a comparable direction to the other indices. The index varies between 0 and 100, with a reading above 50 indicating an overall increase compared to the previous month, and below 50 an overall decrease.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'S&P Global',
#   'source_url': 'https://www.pmi.spglobal.com/public',
#   'actual': None,
#   'previous': 51.3,
#   'forecast': 51,
#   'actualRaw': None,
#   'previousRaw': 51.3,
#   'forecastRaw': 51,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-21T13:45:00.000Z'},
#  {'id': '353332',
#   'title': 'S&P Global Services PMI Flash',
#   'country': 'US',
#   'indicator': 'Services PMI',
#   'ticker': 'ECONOMICS:USSPMI',
#   'comment': 'The S&P Global US Services PMI is compiled by S&P Global from responses to questionnaires sent to a panel of around 400 service sector companies. The sectors covered include consumer (excluding retail), transport, information, communication, finance, insurance, real estate and business services. The index tracks variables such as sales, employment, inventories and prices; and varies between 0 and 100, with a reading above 50 indicating an overall increase compared to the previous month, and below 50 an overall decrease. The headline figure is the Services Business Activity Index, which is a diffusion index calculated from a question that asks for changes in the volume of business activity compared with one month previously. The Services Business Activity Index is comparable to the Manufacturing Output Index.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'S&P Global',
#   'source_url': 'https://www.pmi.spglobal.com/public',
#   'actual': None,
#   'previous': 54.8,
#   'forecast': 53.3,
#   'actualRaw': None,
#   'previousRaw': 54.8,
#   'forecastRaw': 53.3,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-21T13:45:00.000Z'},
#  {'id': '353333',
#   'title': 'S&P Global Composite PMI Flash',
#   'country': 'US',
#   'indicator': 'Composite PMI',
#   'ticker': 'ECONOMICS:USCOMPPMI',
#   'comment': 'In the United States, the S&P Global Composite PMI Output Index, which is a weighted average of the Manufacturing Output Index and the Services Business Activity Index, tracks business trends across both manufacturing and service sectors. The index is based on data collected from a representative panel of over 800 companies and follows variables such as sales, new orders, employment, inventories and prices. A reading above 50 indicates expansion in business activity while below 50 points to contraction.',
#   'category': 'bsnss',
#   'period': 'Jun',
#   'source': 'S&P Global',
#   'source_url': 'https://www.pmi.spglobal.com/public',
#   'actual': None,
#   'previous': 54.5,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 54.5,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': 0,
#   'date': '2024-06-21T13:45:00.000Z'},
#  {'id': '353245',
#   'title': 'Existing Home Sales MoM',
#   'country': 'US',
#   'indicator': 'Existing Home Sales MoM',
#   'ticker': 'ECONOMICS:USEHSMM',
#   'comment': 'In the United States, Existing Home Sales occur when the mortgages are closed. Mortgage closing usually takes place 30-60 days after the sales contract is closed.',
#   'category': 'hse',
#   'period': 'May',
#   'source': 'National Association of Realtors',
#   'source_url': 'https://www.nar.realtor',
#   'actual': None,
#   'previous': -1.9,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': -1.9,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': 0,
#   'date': '2024-06-21T14:00:00.000Z'},
#  {'id': '353246',
#   'title': 'Existing Home Sales',
#   'country': 'US',
#   'indicator': 'Existing Home Sales',
#   'ticker': 'ECONOMICS:USEHS',
#   'comment': 'In the United States, Existing Home Sales occur when the mortgages are closed. Mortgage closing usually takes place 30-60 days after the sales contract is closed. It includes single-family homes, condos and co-ops.',
#   'category': 'hse',
#   'period': 'May',
#   'source': 'National Association of Realtors',
#   'source_url': 'https://www.nar.realtor',
#   'actual': None,
#   'previous': 4.14,
#   'forecast': 4.09,
#   'actualRaw': None,
#   'previousRaw': 4139999.9999999995,
#   'forecastRaw': 4090000,
#   'currency': 'USD',
#   'scale': 'M',
#   'importance': 0,
#   'date': '2024-06-21T14:00:00.000Z'},
#  {'id': '353247',
#   'title': 'CB Leading Index MoM',
#   'country': 'US',
#   'indicator': 'Calendar',
#   'comment': 'The Conference Board Leading Economic Index is a predictive variable that anticipates (or “leads”) turning points in the business cycle by around 7 months. The ten components of The Conference Board Leading Economic Index® for the U.S. include: Average weekly hours in manufacturing; Average weekly initial claims for unemployment insurance; Manufacturers’ new orders for consumer goods and materials; ISM® Index of New Orders; Manufacturers’ new orders for nondefense capital goods excluding aircraft orders; Building permits for new private housing units; S&P 500® Index of Stock Prices; Leading Credit Index™; Interest rate spread (10-year Treasury bonds less federal funds rate); Average consumer expectations for business conditions.',
#   'category': 'gov',
#   'period': 'May',
#   'source': '',
#   'source_url': '',
#   'actual': None,
#   'previous': -0.6,
#   'forecast': -0.4,
#   'actualRaw': None,
#   'previousRaw': -0.6,
#   'forecastRaw': -0.4,
#   'currency': 'USD',
#   'unit': '%',
#   'importance': -1,
#   'date': '2024-06-21T14:00:00.000Z'},
#  {'id': '343317',
#   'title': 'EIA Natural Gas Stocks Change',
#   'country': 'US',
#   'indicator': 'Natural Gas Stocks Change',
#   'ticker': 'ECONOMICS:USNGSC',
#   'comment': 'Natural Gas Stocks Change refers to the weekly change of the natural gas supply situation.',
#   'period': 'Jun/14',
#   'source': 'U.S. Energy Information Administration',
#   'source_url': 'http://www.eia.gov/',
#   'actual': None,
#   'previous': 74,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 74000000000,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'unit': 'cf',
#   'scale': 'B',
#   'importance': -1,
#   'date': '2024-06-21T14:30:00.000Z'},
#  {'id': '343325',
#   'title': 'Baker Hughes Oil Rig Count',
#   'country': 'US',
#   'indicator': 'Crude Oil Rigs',
#   'ticker': 'ECONOMICS:USCOR',
#   'comment': 'US Crude Oil Rigs refer to the number of active US rigs drilling for oil in a given week.',
#   'period': 'Jun/21',
#   'source': 'Baker Hughes Company',
#   'source_url': 'https://www.bakerhughes.com/',
#   'actual': None,
#   'previous': 488,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 488,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-21T17:00:00.000Z'},
#  {'id': '343326',
#   'title': 'Baker Hughes Total Rigs Count',
#   'country': 'US',
#   'indicator': 'Total Rigs',
#   'ticker': 'ECONOMICS:USTRG',
#   'comment': 'US Total Rigs refer to the number of active US rigs drilling in a given week.',
#   'period': 'Jun/21',
#   'source': 'Baker Hughes Company',
#   'source_url': 'https://www.bakerhughes.com/',
#   'actual': None,
#   'previous': 590,
#   'forecast': None,
#   'actualRaw': None,
#   'previousRaw': 590,
#   'forecastRaw': None,
#   'currency': 'USD',
#   'importance': -1,
#   'date': '2024-06-21T17:00:00.000Z'}]
